# %%
# %matplotlib inline

from __future__ import print_function
import numpy as np
import theano
from scipy.misc import imresize, imread
import matplotlib.pyplot as plt

# %% [markdown]
# # Setting and Getting shared variables in Theano

# %%
w = np.random.randn(3, 2)
W = theano.shared(np.zeros((3, 2)))
print(W.get_value())
W.set_value(w)
print(W.get_value())
# Out:
# [[ 0.  0.]
#  [ 0.  0.]
#  [ 0.  0.]]
# [[-0.05685074  0.70964101]
#  [-0.03834757  0.3255286 ]
#  [ 0.46718085  0.14045352]]

# %% [markdown]
# # Classifying with <a href = "http://sklearn-theano.github.io">sklearn-Theano</a> and Overfeat

# %%
cat = imresize(imread('287.jpg'), [231, 231])
dog = imresize(imread('Siberian_Husky_Dog_5.jpg'), [231, 231])

plt.subplot(121)
plt.imshow(cat)
plt.subplot(122)
plt.imshow(dog)

# %%
from sklearn_theano.feature_extraction import OverfeatClassifier
clf = OverfeatClassifier(top_n = 5)

# %%
clf.predict(cat)
# Out:
# array([['Persian cat', 'lynx, catamount', 'tiger cat', 'tabby, tabby cat',
#         'Egyptian cat']], dtype=object)

# %%
clf.predict(dog)
# Out:
# array([['kelpie', 'Cardigan, Cardigan Welsh corgi',
#         'malamute, malemute, Alaskan malamute', 'Siberian husky',
#         'Eskimo dog, husky']], dtype=object)
